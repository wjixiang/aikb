# %%
from dx_client import DXClient

# %%
client = DXClient()

# %%
client.connect()
# Out:
# ---------------------------------------------------------------------------
# DXConfigError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client.connect()
#
# File /mnt/disk1/project/MedCross/libs/dx-client/src/dx_client/dx_client.py:122, in DXClient.connect(self)
#     119     return
#     121 if not self._config.auth_token:
# --> 122     raise DXConfigError(
#     123         "DNAnexus auth token is required. "
#     124         "Set DX_AUTH_TOKEN environment variable or pass config.auth_token."
#     125     )
#     127 dxpy.set_security_context(
#     128     {"auth_token_type": "Bearer", "auth_token": self._config.auth_token}
#     129 )
#     131 dxpy.set_api_server_info(
#     132     host=self._config.api_server_host,
#     133     port=self._config.api_server_port,
#     134     protocol=self._config.api_server_protocol,
#     135 )
#
# ...
